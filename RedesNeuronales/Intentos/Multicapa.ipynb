# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import time

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Flatten(),
        layers.Dense(64, activation="relu"),
        layers.Dropout(0.2),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 59,850
# Trainable params: 59,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 25

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

start = time.time()
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
end = time.time()
# Out:
# Epoch 1/25
# 422/422 [==============================] - 2s 5ms/step - loss: 0.5992 - accuracy: 0.8149 - val_loss: 0.1871 - val_accuracy: 0.9462
# Epoch 2/25
# 422/422 [==============================] - 2s 5ms/step - loss: 0.2974 - accuracy: 0.9086 - val_loss: 0.1312 - val_accuracy: 0.9617
# Epoch 3/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.2420 - accuracy: 0.9266 - val_loss: 0.1100 - val_accuracy: 0.9688
# Epoch 4/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.2089 - accuracy: 0.9356 - val_loss: 0.0954 - val_accuracy: 0.9713
# Epoch 5/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1872 - accuracy: 0.9424 - val_loss: 0.0844 - val_accuracy: 0.9758
# Epoch 6/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1748 - accuracy: 0.9463 - val_loss: 0.0827 - val_accuracy: 0.9758
# Epoch 7/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1627 - accuracy: 0.9491 - val_loss: 0.0772 - val_accuracy: 0.9770
# Epoch 8/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1537 - accuracy: 0.9518 - val_loss: 0.0740 - val_accuracy: 0.9800
# Epoch 9/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1519 - accuracy: 0.9528 - val_loss: 0.0736 - val_accuracy: 0.9798
# Epoch 10/25
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1430 - accuracy: 0.9549 - val_loss: 0.0734 - val_accuracy: 0.9787
# Epoch 11/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1387 - accuracy: 0.9566 - val_loss: 0.0694 - val_accuracy: 0.9788
# Epoch 12/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1318 - accuracy: 0.9586 - val_loss: 0.0695 - val_accuracy: 0.9797
# Epoch 13/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1271 - accuracy: 0.9600 - val_loss: 0.0669 - val_accuracy: 0.9808
# Epoch 14/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1269 - accuracy: 0.9603 - val_loss: 0.0687 - val_accuracy: 0.9790
# Epoch 15/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1241 - accuracy: 0.9607 - val_loss: 0.0689 - val_accuracy: 0.9805
# Epoch 16/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1194 - accuracy: 0.9619 - val_loss: 0.0657 - val_accuracy: 0.9805
# Epoch 17/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1213 - accuracy: 0.9605 - val_loss: 0.0684 - val_accuracy: 0.9815
# Epoch 18/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1159 - accuracy: 0.9632 - val_loss: 0.0674 - val_accuracy: 0.9828
# Epoch 19/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1116 - accuracy: 0.9648 - val_loss: 0.0681 - val_accuracy: 0.9815
# Epoch 20/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1123 - accuracy: 0.9647 - val_loss: 0.0664 - val_accuracy: 0.9813
# Epoch 21/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1091 - accuracy: 0.9649 - val_loss: 0.0637 - val_accuracy: 0.9810
# Epoch 22/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1090 - accuracy: 0.9651 - val_loss: 0.0657 - val_accuracy: 0.9820
# Epoch 23/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1071 - accuracy: 0.9661 - val_loss: 0.0640 - val_accuracy: 0.9827
# Epoch 24/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1044 - accuracy: 0.9669 - val_loss: 0.0669 - val_accuracy: 0.9800
# Epoch 25/25
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1034 - accuracy: 0.9667 - val_loss: 0.0635 - val_accuracy: 0.9805

# %%
score_test = model.evaluate(x_test, y_test, verbose=0)
score_train = model.evaluate(x_train, y_train, verbose=0)
outputs = model.predict(x_test)

for output in outputs:
  print(np.argmax(output), end='')

print("")
print("Error sobre el conjunto de prueba:", (1-score_test[1])*100)
print("Error sobre el conjunto de entrenamiento:", (1-score_train[1])*100)
print("Tiempo de entrenamiento: "+str(round(end - start,2)))
print("Epoch:", epochs)
# Out:
# ...
# Error sobre el conjunto de prueba: 2.0200014114379883
# Error sobre el conjunto de entrenamiento: 1.0633349418640137
# Tiempo de entrenamiento: 45.79
# Epoch: 25
